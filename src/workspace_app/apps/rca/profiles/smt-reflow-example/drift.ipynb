# %% [markdown]
# # SPC drift analysis
#
# Load process signals and overlay defect events to find drift onsets.

# %%
import pandas as pd

# Load fixture data — replace with the probe relevant to this investigation.
z3 = pd.read_csv("/workspace/data/reflow.zone3.sample.csv", parse_dates=["ts"])
z3.head()
