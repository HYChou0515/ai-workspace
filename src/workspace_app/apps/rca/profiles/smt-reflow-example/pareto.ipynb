# %% [markdown]
# # Pareto of failure modes
#
# Rank defect categories by count to find the vital few.

# %%
# Bin defect counts and plot the top-N with cumulative-% overlay.
# Agent fills this in with real data once it identifies defect sources.
